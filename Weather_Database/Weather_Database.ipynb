# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities
cities = []
# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bc410ec95229b328ec759306d5e17889

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # read the list to a temp and then read the actual description
        city_weatherdesc_temp = city_weather["weather"][0]
        city_weatherdesc = city_weatherdesc_temp["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weatherdesc
                          })

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | saint-philippe
# Processing Record 2 of Set 1 | norman wells
# Processing Record 3 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 1 | rosarito
# Processing Record 5 of Set 1 | buala
# Processing Record 6 of Set 1 | cape town
# Processing Record 7 of Set 1 | dalinghe
# City not found. Skipping...
# Processing Record 8 of Set 1 | nago
# Processing Record 9 of Set 1 | liberty
# Processing Record 10 of Set 1 | asau
# Processing Record 11 of Set 1 | provideniya
# Processing Record 12 of Set 1 | cabo san lucas
# Processing Record 13 of Set 1 | kapaa
# Processing Record 14 of Set 1 | samarai
# Processing Record 15 of Set 1 | qianan
# Processing Record 16 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 1 | bengkulu
# Processing Record 18 of Set 1 | talnakh
# Processing Record 19 of Set 1 | albany
# Processing Record 20 of Set 1 | villefontaine
# Processing Record 21 of Set 1 | sitka
# Processing Record 22 of Set 1 | naze
# Processing Record 23 of Set 1 | rikitea
# Processing Record 24 of Set 1 | marawi
# Processing Record 25 of Set 1 | tuktoyaktuk
# Processing Record 26 of Set 1 | yellowknife
# Processing Record 27 of Set 1 | puerto ayora
# Processing Record 28 of Set 1 | new norfolk
# Processing Record 29 of Set 1 | ploemeur
# Processing Record 30 of Set 1 | avarua
# Processing Record 31 of Set 1 | rio grande
# Processing Record 32 of Set 1 | ushuaia
# Processing Record 33 of Set 1 | port alfred
# Processing Record 34 of Set 1 | arraial do cabo
# Processing Record 35 of Set 1 | auki
# Processing Record 36 of Set 1 | lompoc
# Processing Record 37 of Set 1 | grimshaw
# Processing Record 38 of Set 1 | atuona
# Processing Record 39 of Set 1 | khatanga
# Processing Record 40 of Set 1 | ryotsu
# Processing Record 41 of Set 1 | riyadh
# Processing Record 42 of Set 1 | nikolskoye
# Processing Record 43 of Set 1 | butaritari
# Processing Record 44 of Set 1 | maneadero
# Processing Record 45 of Set 1 | mar del plata
# Processing Record 46 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 47 of Set 1 | yarada
# Processing Record 48 of Set 1 | biograd na moru
# Processing Record 49 of Set 1 | nador
# Processing Record 50 of Set 1 | busselton
# Processing Record 1 of Set 2 | barrow
# Processing Record 2 of Set 2 | hermanus
# Processing Record 3 of Set 2 | sayansk
# Processing Record 4 of Set 2 | vaini
# Processing Record 5 of Set 2 | unye
# City not found. Skipping...
# Processing Record 6 of Set 2 | clyde river
# Processing Record 7 of Set 2 | bredasdorp
# Processing Record 8 of Set 2 | cortes
# Processing Record 9 of Set 2 | formoso do araguaia
# City not found. Skipping...
# Processing Record 10 of Set 2 | vrangel
# Processing Record 11 of Set 2 | nanortalik
# Processing Record 12 of Set 2 | bathsheba
# Processing Record 13 of Set 2 | torfyanoy
# Processing Record 14 of Set 2 | hobart
# Processing Record 15 of Set 2 | mataura
# Processing Record 16 of Set 2 | kuopio
# Processing Record 17 of Set 2 | bluff
# Processing Record 18 of Set 2 | castro
# Processing Record 19 of Set 2 | lakhnadon
# Processing Record 20 of Set 2 | zhigansk
# Processing Record 21 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 22 of Set 2 | qaanaaq
# Processing Record 23 of Set 2 | pangody
# Processing Record 24 of Set 2 | labuhan
# Processing Record 25 of Set 2 | mangan
# Processing Record 26 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 27 of Set 2 | baruun-urt
# Processing Record 28 of Set 2 | yasnyy
# Processing Record 29 of Set 2 | fare
# Processing Record 30 of Set 2 | bogotol
# Processing Record 31 of Set 2 | faya
# Processing Record 32 of Set 2 | hofn
# Processing Record 33 of Set 2 | chokurdakh
# Processing Record 34 of Set 2 | ribeira grande
# Processing Record 35 of Set 2 | wagga wagga
# Processing Record 36 of Set 2 | evensk
# Processing Record 37 of Set 2 | parana
# Processing Record 38 of Set 2 | nsanje
# Processing Record 39 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 40 of Set 2 | ilulissat
# Processing Record 41 of Set 2 | leningradskiy
# Processing Record 42 of Set 2 | grand gaube
# Processing Record 43 of Set 2 | benalla
# Processing Record 44 of Set 2 | jamestown
# Processing Record 45 of Set 2 | vezirkopru
# Processing Record 46 of Set 2 | pirovskoye
# Processing Record 47 of Set 2 | pangnirtung
# Processing Record 48 of Set 2 | katsuura
# Processing Record 49 of Set 2 | tilichiki
# Processing Record 50 of Set 2 | moose factory
# Processing Record 1 of Set 3 | mogadishu
# Processing Record 2 of Set 3 | carnarvon
# Processing Record 3 of Set 3 | maun
# Processing Record 4 of Set 3 | cidreira
# Processing Record 5 of Set 3 | tiksi
# Processing Record 6 of Set 3 | noumea
# Processing Record 7 of Set 3 | freeport
# Processing Record 8 of Set 3 | zharkent
# Processing Record 9 of Set 3 | hilo
# Processing Record 10 of Set 3 | karratha
# Processing Record 11 of Set 3 | caohai
# Processing Record 12 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 3 | severo-kurilsk
# Processing Record 14 of Set 3 | upernavik
# Processing Record 15 of Set 3 | joigny
# Processing Record 16 of Set 3 | lebu
# Processing Record 17 of Set 3 | mount gambier
# Processing Record 18 of Set 3 | yatou
# Processing Record 19 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 20 of Set 3 | finschhafen
# Processing Record 21 of Set 3 | yanliang
# Processing Record 22 of Set 3 | fortuna
# Processing Record 23 of Set 3 | tasiilaq
# Processing Record 24 of Set 3 | gamboula
# Processing Record 25 of Set 3 | ketchikan
# Processing Record 26 of Set 3 | hami
# Processing Record 27 of Set 3 | othonoi
# City not found. Skipping...
# Processing Record 28 of Set 3 | asfi
# Processing Record 29 of Set 3 | punta arenas
# Processing Record 30 of Set 3 | conceicao da barra
# Processing Record 31 of Set 3 | pemangkat
# Processing Record 32 of Set 3 | batagay
# Processing Record 33 of Set 3 | isangel
# Processing Record 34 of Set 3 | dimitrovgrad
# Processing Record 35 of Set 3 | dabola
# Processing Record 36 of Set 3 | cayenne
# Processing Record 37 of Set 3 | kariba
# Processing Record 38 of Set 3 | teya
# Processing Record 39 of Set 3 | acapulco
# Processing Record 40 of Set 3 | el jicaro
# Processing Record 41 of Set 3 | uyuni
# Processing Record 42 of Set 3 | narsaq
# Processing Record 43 of Set 3 | antofagasta
# Processing Record 44 of Set 3 | kudahuvadhoo
# Processing Record 45 of Set 3 | port elizabeth
# Processing Record 46 of Set 3 | ahipara
# Processing Record 47 of Set 3 | mayo
# Processing Record 48 of Set 3 | puri
# Processing Record 49 of Set 3 | hithadhoo
# Processing Record 50 of Set 3 | faanui
# Processing Record 1 of Set 4 | atar
# Processing Record 2 of Set 4 | blackfoot
# Processing Record 3 of Set 4 | east london
# Processing Record 4 of Set 4 | vila franca do campo
# Processing Record 5 of Set 4 | porbandar
# Processing Record 6 of Set 4 | rovnoye
# Processing Record 7 of Set 4 | narasannapeta
# Processing Record 8 of Set 4 | san lazaro
# Processing Record 9 of Set 4 | kanniyakumari
# Processing Record 10 of Set 4 | longyearbyen
# Processing Record 11 of Set 4 | san patricio
# Processing Record 12 of Set 4 | loncoche
# Processing Record 13 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 14 of Set 4 | barbar
# City not found. Skipping...
# Processing Record 15 of Set 4 | erzurum
# Processing Record 16 of Set 4 | rundu
# Processing Record 17 of Set 4 | puerto escondido
# Processing Record 18 of Set 4 | kuruman
# Processing Record 19 of Set 4 | jinxiang
# Processing Record 20 of Set 4 | coromandel
# Processing Record 21 of Set 4 | bambous virieux
# Processing Record 22 of Set 4 | niquelandia
# Processing Record 23 of Set 4 | kahului
# Processing Record 24 of Set 4 | mayumba
# Processing Record 25 of Set 4 | seymchan
# Processing Record 26 of Set 4 | dekar
# Processing Record 27 of Set 4 | hambantota
# Processing Record 28 of Set 4 | dikson
# Processing Record 29 of Set 4 | honiara
# Processing Record 30 of Set 4 | nouadhibou
# Processing Record 31 of Set 4 | namibe
# Processing Record 32 of Set 4 | alta floresta
# Processing Record 33 of Set 4 | shetpe
# Processing Record 34 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 35 of Set 4 | ajaccio
# Processing Record 36 of Set 4 | baoqing
# Processing Record 37 of Set 4 | esperance
# Processing Record 38 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 39 of Set 4 | bethel
# Processing Record 40 of Set 4 | luderitz
# Processing Record 41 of Set 4 | batemans bay
# Processing Record 42 of Set 4 | satitoa
# City not found. Skipping...
# Processing Record 43 of Set 4 | alice springs
# Processing Record 44 of Set 4 | mwingi
# Processing Record 45 of Set 4 | saint-augustin
# Processing Record 46 of Set 4 | aksu
# Processing Record 47 of Set 4 | thompson
# Processing Record 48 of Set 4 | ulaangom
# Processing Record 49 of Set 4 | haputale
# Processing Record 50 of Set 4 | thyboron
# Processing Record 1 of Set 5 | guerrero negro
# Processing Record 2 of Set 5 | madison
# Processing Record 3 of Set 5 | poli
# Processing Record 4 of Set 5 | aklavik
# Processing Record 5 of Set 5 | ugoofaaru
# Processing Record 6 of Set 5 | teahupoo
# Processing Record 7 of Set 5 | harper
# Processing Record 8 of Set 5 | saint-pierre
# Processing Record 9 of Set 5 | kumluca
# Processing Record 10 of Set 5 | port-cartier
# Processing Record 11 of Set 5 | tingi
# Processing Record 12 of Set 5 | georgetown
# Processing Record 13 of Set 5 | sataua
# City not found. Skipping...
# Processing Record 14 of Set 5 | rincon
# Processing Record 15 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 16 of Set 5 | mayachnyy
# Processing Record 17 of Set 5 | berlevag
# Processing Record 18 of Set 5 | tuatapere
# Processing Record 19 of Set 5 | eskasem
# City not found. Skipping...
# Processing Record 20 of Set 5 | hunucma
# Processing Record 21 of Set 5 | hasaki
# Processing Record 22 of Set 5 | kodiak
# Processing Record 23 of Set 5 | santa maria
# Processing Record 24 of Set 5 | shitkino
# Processing Record 25 of Set 5 | hamilton
# Processing Record 26 of Set 5 | umm lajj
# Processing Record 27 of Set 5 | ayan
# Processing Record 28 of Set 5 | pokhara
# Processing Record 29 of Set 5 | jaisalmer
# Processing Record 30 of Set 5 | pevek
# Processing Record 31 of Set 5 | teresopolis
# Processing Record 32 of Set 5 | bubaque
# Processing Record 33 of Set 5 | forest hills
# Processing Record 34 of Set 5 | vardo
# Processing Record 35 of Set 5 | aksha
# Processing Record 36 of Set 5 | beipiao
# Processing Record 37 of Set 5 | tidore
# City not found. Skipping...
# Processing Record 38 of Set 5 | igunga
# Processing Record 39 of Set 5 | todos santos
# Processing Record 40 of Set 5 | upington
# Processing Record 41 of Set 5 | vila
# Processing Record 42 of Set 5 | weihe
# Processing Record 43 of Set 5 | sorong
# Processing Record 44 of Set 5 | juegang
# Processing Record 45 of Set 5 | cabedelo
# Processing Record 46 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 47 of Set 5 | mohiuddinagar
# City not found. Skipping...
# Processing Record 48 of Set 5 | cherskiy
# Processing Record 49 of Set 5 | tambopata
# Processing Record 50 of Set 5 | puerto del rosario
# Processing Record 1 of Set 6 | bandarbeyla
# Processing Record 2 of Set 6 | oxapampa
# Processing Record 3 of Set 6 | opuwo
# Processing Record 4 of Set 6 | shache
# Processing Record 5 of Set 6 | mahebourg
# Processing Record 6 of Set 6 | nicoya
# Processing Record 7 of Set 6 | timbiqui
# Processing Record 8 of Set 6 | saint-denis
# Processing Record 9 of Set 6 | sumbe
# Processing Record 10 of Set 6 | impfondo
# Processing Record 11 of Set 6 | coihaique
# Processing Record 12 of Set 6 | mineros
# Processing Record 13 of Set 6 | xuddur
# Processing Record 14 of Set 6 | erenhot
# Processing Record 15 of Set 6 | wagar
# Processing Record 16 of Set 6 | poya
# Processing Record 17 of Set 6 | sambava
# Processing Record 18 of Set 6 | dharmadam
# Processing Record 19 of Set 6 | concepcion del uruguay
# Processing Record 20 of Set 6 | saint george
# Processing Record 21 of Set 6 | lebyazhye
# Processing Record 22 of Set 6 | guarapari
# Processing Record 23 of Set 6 | pisco
# Processing Record 24 of Set 6 | middelburg
# Processing Record 25 of Set 6 | kitimat
# Processing Record 26 of Set 6 | gravdal
# Processing Record 27 of Set 6 | mul
# Processing Record 28 of Set 6 | pastavy
# Processing Record 29 of Set 6 | conde
# Processing Record 30 of Set 6 | ouegoa
# Processing Record 31 of Set 6 | george town
# Processing Record 32 of Set 6 | chuy
# Processing Record 33 of Set 6 | lagoa
# Processing Record 34 of Set 6 | awjilah
# Processing Record 35 of Set 6 | dingle
# Processing Record 36 of Set 6 | merrill
# Processing Record 37 of Set 6 | torbay
# Processing Record 38 of Set 6 | bourail
# Processing Record 39 of Set 6 | victoria
# Processing Record 40 of Set 6 | iqaluit
# Processing Record 41 of Set 6 | voi
# Processing Record 42 of Set 6 | dakar
# Processing Record 43 of Set 6 | boromo
# Processing Record 44 of Set 6 | ituni
# City not found. Skipping...
# Processing Record 45 of Set 6 | saskylakh
# Processing Record 46 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 47 of Set 6 | pingliang
# Processing Record 48 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 49 of Set 6 | elizabeth city
# Processing Record 50 of Set 6 | necochea
# Processing Record 1 of Set 7 | alofi
# Processing Record 2 of Set 7 | pathein
# Processing Record 3 of Set 7 | tonantins
# Processing Record 4 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 5 of Set 7 | sao filipe
# Processing Record 6 of Set 7 | ola
# Processing Record 7 of Set 7 | saldanha
# Processing Record 8 of Set 7 | kununurra
# Processing Record 9 of Set 7 | jeremoabo
# Processing Record 10 of Set 7 | liepaja
# Processing Record 11 of Set 7 | sibolga
# Processing Record 12 of Set 7 | geraldton
# Processing Record 13 of Set 7 | kruisfontein
# Processing Record 14 of Set 7 | carroll
# Processing Record 15 of Set 7 | half moon bay
# Processing Record 16 of Set 7 | souillac
# Processing Record 17 of Set 7 | camana
# Processing Record 18 of Set 7 | meulaboh
# Processing Record 19 of Set 7 | camacupa
# Processing Record 20 of Set 7 | codrington
# Processing Record 21 of Set 7 | port augusta
# Processing Record 22 of Set 7 | moron
# Processing Record 23 of Set 7 | constitucion
# Processing Record 24 of Set 7 | kutum
# Processing Record 25 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 26 of Set 7 | hobyo
# Processing Record 27 of Set 7 | jishui
# Processing Record 28 of Set 7 | san jose
# Processing Record 29 of Set 7 | arman
# Processing Record 30 of Set 7 | yeppoon
# Processing Record 31 of Set 7 | waddan
# Processing Record 32 of Set 7 | rumford
# Processing Record 33 of Set 7 | vila velha
# Processing Record 34 of Set 7 | puerto ayacucho
# Processing Record 35 of Set 7 | barra
# Processing Record 36 of Set 7 | khromtau
# Processing Record 37 of Set 7 | miramar
# Processing Record 38 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 39 of Set 7 | adrar
# Processing Record 40 of Set 7 | zhezkazgan
# Processing Record 41 of Set 7 | paamiut
# Processing Record 42 of Set 7 | hovd
# Processing Record 43 of Set 7 | azimur
# City not found. Skipping...
# Processing Record 44 of Set 7 | avera
# Processing Record 45 of Set 7 | praya
# Processing Record 46 of Set 7 | mehamn
# Processing Record 47 of Set 7 | merauke
# Processing Record 48 of Set 7 | porkhov
# Processing Record 49 of Set 7 | norsup
# Processing Record 50 of Set 7 | bac lieu
# Processing Record 1 of Set 8 | evansville
# Processing Record 2 of Set 8 | mozarlandia
# Processing Record 3 of Set 8 | ankang
# Processing Record 4 of Set 8 | byumba
# Processing Record 5 of Set 8 | eureka
# Processing Record 6 of Set 8 | bonthe
# Processing Record 7 of Set 8 | pinsk
# Processing Record 8 of Set 8 | santa rosa
# Processing Record 9 of Set 8 | la rioja
# Processing Record 10 of Set 8 | vilhena
# Processing Record 11 of Set 8 | baherden
# Processing Record 12 of Set 8 | hualmay
# Processing Record 13 of Set 8 | barra do corda
# Processing Record 14 of Set 8 | shirvan
# Processing Record 15 of Set 8 | bahraich
# Processing Record 16 of Set 8 | polewali
# Processing Record 17 of Set 8 | jakar
# Processing Record 18 of Set 8 | san juan tecuaco
# Processing Record 19 of Set 8 | geresk
# City not found. Skipping...
# Processing Record 20 of Set 8 | eskisehir
# Processing Record 21 of Set 8 | broome
# Processing Record 22 of Set 8 | phan thiet
# Processing Record 23 of Set 8 | tessalit
# Processing Record 24 of Set 8 | miandoab
# Processing Record 25 of Set 8 | shu
# Processing Record 26 of Set 8 | yuza
# Processing Record 27 of Set 8 | joshimath
# Processing Record 28 of Set 8 | trairi
# Processing Record 29 of Set 8 | springbok
# Processing Record 30 of Set 8 | tacoronte
# Processing Record 31 of Set 8 | kieta
# Processing Record 32 of Set 8 | morgan city
# Processing Record 33 of Set 8 | ulladulla
# Processing Record 34 of Set 8 | sorland
# Processing Record 35 of Set 8 | portland
# Processing Record 36 of Set 8 | mumford
# Processing Record 37 of Set 8 | derzhavinsk
# Processing Record 38 of Set 8 | lasa
# Processing Record 39 of Set 8 | prince rupert
# Processing Record 40 of Set 8 | kasongo-lunda
# Processing Record 41 of Set 8 | duldurga
# Processing Record 42 of Set 8 | kloulklubed
# Processing Record 43 of Set 8 | vredendal
# Processing Record 44 of Set 8 | mali
# Processing Record 45 of Set 8 | touros
# Processing Record 46 of Set 8 | peniche
# Processing Record 47 of Set 8 | oranjemund
# Processing Record 48 of Set 8 | salekhard
# Processing Record 49 of Set 8 | bata
# Processing Record 50 of Set 8 | cheltenham
# Processing Record 1 of Set 9 | sao miguel do oeste
# City not found. Skipping...
# Processing Record 2 of Set 9 | vestmannaeyjar
# Processing Record 3 of Set 9 | mnogovershinnyy
# Processing Record 4 of Set 9 | sioux lookout
# Processing Record 5 of Set 9 | sisimiut
# Processing Record 6 of Set 9 | abha
# Processing Record 7 of Set 9 | seoul
# Processing Record 8 of Set 9 | tapejara
# Processing Record 9 of Set 9 | kaitangata
# Processing Record 10 of Set 9 | ponnani
# Processing Record 11 of Set 9 | jacksonville
# Processing Record 12 of Set 9 | bom jesus
# Processing Record 13 of Set 9 | port blair
# Processing Record 14 of Set 9 | calvinia
# Processing Record 15 of Set 9 | subtanjalla
# Processing Record 16 of Set 9 | ostrovnoy
# Processing Record 17 of Set 9 | havoysund
# Processing Record 18 of Set 9 | nampula
# Processing Record 19 of Set 9 | bay roberts
# Processing Record 20 of Set 9 | ondjiva
# Processing Record 21 of Set 9 | atagay
# Processing Record 22 of Set 9 | tadine
# Processing Record 23 of Set 9 | padang
# Processing Record 24 of Set 9 | devyatka
# City not found. Skipping...
# Processing Record 25 of Set 9 | kavieng
# Processing Record 26 of Set 9 | vallenar
# Processing Record 27 of Set 9 | nortelandia
# Processing Record 28 of Set 9 | el alto
# Processing Record 29 of Set 9 | wanning
# Processing Record 30 of Set 9 | cap malheureux
# Processing Record 31 of Set 9 | telhara
# Processing Record 32 of Set 9 | koslan
# Processing Record 33 of Set 9 | benguela
# Processing Record 34 of Set 9 | bilimbay
# Processing Record 35 of Set 9 | mbini
# Processing Record 36 of Set 9 | mabaruma
# Processing Record 37 of Set 9 | caravelas
# Processing Record 38 of Set 9 | caxito
# Processing Record 39 of Set 9 | the valley
# Processing Record 40 of Set 9 | maldonado
# Processing Record 41 of Set 9 | megalopoli
# Processing Record 42 of Set 9 | slavgorod
# Processing Record 43 of Set 9 | boldumsaz
# Processing Record 44 of Set 9 | kribi
# Processing Record 45 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 46 of Set 9 | plouzane
# Processing Record 47 of Set 9 | velsk
# Processing Record 48 of Set 9 | rawson
# Processing Record 49 of Set 9 | goudomp
# City not found. Skipping...
# Processing Record 50 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 1 of Set 10 | laguna
# Processing Record 2 of Set 10 | roald
# Processing Record 3 of Set 10 | dindori
# Processing Record 4 of Set 10 | taltal
# Processing Record 5 of Set 10 | santa rosa del sur
# Processing Record 6 of Set 10 | abbeville
# Processing Record 7 of Set 10 | tucuma
# Processing Record 8 of Set 10 | jorpeland
# Processing Record 9 of Set 10 | nantucket
# Processing Record 10 of Set 10 | kegayli
# City not found. Skipping...
# Processing Record 11 of Set 10 | halifax
# Processing Record 12 of Set 10 | praia
# Processing Record 13 of Set 10 | phuket
# Processing Record 14 of Set 10 | jutai
# Processing Record 15 of Set 10 | gondang
# Processing Record 16 of Set 10 | champerico
# Processing Record 17 of Set 10 | rosh pinna
# Processing Record 18 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 19 of Set 10 | drezna
# Processing Record 20 of Set 10 | bonavista
# Processing Record 21 of Set 10 | burns lake
# Processing Record 22 of Set 10 | mecca
# Processing Record 23 of Set 10 | road town
# Processing Record 24 of Set 10 | moerai
# Processing Record 25 of Set 10 | columbia
# Processing Record 26 of Set 10 | port hueneme
# Processing Record 27 of Set 10 | udachnyy
# Processing Record 28 of Set 10 | hillsborough
# Processing Record 29 of Set 10 | susanville
# Processing Record 30 of Set 10 | college
# Processing Record 31 of Set 10 | jalu
# Processing Record 32 of Set 10 | port hedland
# Processing Record 33 of Set 10 | baykit
# Processing Record 34 of Set 10 | khorinsk
# Processing Record 35 of Set 10 | tumarbong
# Processing Record 36 of Set 10 | airai
# Processing Record 37 of Set 10 | massakory
# Processing Record 38 of Set 10 | kalmunai
# Processing Record 39 of Set 10 | yinchuan
# Processing Record 40 of Set 10 | porvoo
# Processing Record 41 of Set 10 | lavrentiya
# Processing Record 42 of Set 10 | manati
# Processing Record 43 of Set 10 | truth or consequences
# Processing Record 44 of Set 10 | morondava
# Processing Record 45 of Set 10 | rocha
# Processing Record 46 of Set 10 | ambon
# Processing Record 47 of Set 10 | coquimbo
# Processing Record 48 of Set 10 | sergeyevka
# Processing Record 49 of Set 10 | puerto baquerizo moreno
# Processing Record 50 of Set 10 | ranong
# Processing Record 1 of Set 11 | mabay
# Processing Record 2 of Set 11 | saint-louis
# Processing Record 3 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 4 of Set 11 | sobolevo
# Processing Record 5 of Set 11 | laureles
# Processing Record 6 of Set 11 | sao joao da barra
# Processing Record 7 of Set 11 | vanimo
# Processing Record 8 of Set 11 | wamba
# Processing Record 9 of Set 11 | lemon tree passage
# Processing Record 10 of Set 11 | khilchipur
# Processing Record 11 of Set 11 | richards bay
# Processing Record 12 of Set 11 | glenwood springs
# Processing Record 13 of Set 11 | podor
# Processing Record 14 of Set 11 | vaitape
# Processing Record 15 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 16 of Set 11 | gormi
# City not found. Skipping...
# Processing Record 17 of Set 11 | marang
# Processing Record 18 of Set 11 | ust-nera
# Processing Record 19 of Set 11 | praxedis guerrero
# Processing Record 20 of Set 11 | lyskovo
# Processing Record 21 of Set 11 | johnstown
# Processing Record 22 of Set 11 | cockburn town
# Processing Record 23 of Set 11 | basco
# Processing Record 24 of Set 11 | ambodifototra
# City not found. Skipping...
# Processing Record 25 of Set 11 | san quintin
# Processing Record 26 of Set 11 | surbo
# Processing Record 27 of Set 11 | neiafu
# Processing Record 28 of Set 11 | pochutla
# Processing Record 29 of Set 11 | muros
# Processing Record 30 of Set 11 | bandar penggaram
# City not found. Skipping...
# Processing Record 31 of Set 11 | gat
# Processing Record 32 of Set 11 | fredericksburg
# Processing Record 33 of Set 11 | sinnamary
# Processing Record 34 of Set 11 | khorramshahr
# Processing Record 35 of Set 11 | rania
# Processing Record 36 of Set 11 | sungairaya
# Processing Record 37 of Set 11 | cockburn harbour
# City not found. Skipping...
# Processing Record 38 of Set 11 | timaru
# Processing Record 39 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 40 of Set 11 | jacareacanga
# Processing Record 41 of Set 11 | kinablangan
# Processing Record 42 of Set 11 | quebec
# Processing Record 43 of Set 11 | abu dhabi
# Processing Record 44 of Set 11 | punta alta
# Processing Record 45 of Set 11 | lochem
# Processing Record 46 of Set 11 | basoko
# Processing Record 47 of Set 11 | olafsvik
# Processing Record 48 of Set 11 | ewa beach
# Processing Record 49 of Set 11 | beidao
# Processing Record 50 of Set 11 | coachella
# Processing Record 1 of Set 12 | kiunga
# Processing Record 2 of Set 12 | mackenzie
# Processing Record 3 of Set 12 | gawler
# Processing Record 4 of Set 12 | macaboboni
# City not found. Skipping...
# Processing Record 5 of Set 12 | kozhevnikovo
# Processing Record 6 of Set 12 | winnemucca
# Processing Record 7 of Set 12 | oudtshoorn
# Processing Record 8 of Set 12 | port hawkesbury
# Processing Record 9 of Set 12 | hay river
# Processing Record 10 of Set 12 | porto velho
# Processing Record 11 of Set 12 | grindavik
# Processing Record 12 of Set 12 | kamenka
# Processing Record 13 of Set 12 | ixtapa
# Processing Record 14 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 15 of Set 12 | sinkat
# City not found. Skipping...
# Processing Record 16 of Set 12 | augustow
# Processing Record 17 of Set 12 | omutinskoye
# City not found. Skipping...
# Processing Record 18 of Set 12 | margate
# Processing Record 19 of Set 12 | dodge city
# Processing Record 20 of Set 12 | srednekolymsk
# Processing Record 21 of Set 12 | plettenberg bay
# Processing Record 22 of Set 12 | yala
# Processing Record 23 of Set 12 | sangar
# Processing Record 24 of Set 12 | ponta do sol
# Processing Record 25 of Set 12 | westport
# Processing Record 26 of Set 12 | churapcha
# Processing Record 27 of Set 12 | floro
# Processing Record 28 of Set 12 | selma
# Processing Record 29 of Set 12 | esmeraldas
# Processing Record 30 of Set 12 | cochabamba
# Processing Record 31 of Set 12 | yenagoa
# Processing Record 32 of Set 12 | goulburn
# Processing Record 33 of Set 12 | yongchang
# Processing Record 34 of Set 12 | bani walid
# Processing Record 35 of Set 12 | maltahohe
# Processing Record 36 of Set 12 | kyaukse
# Processing Record 37 of Set 12 | jacqueville
# Processing Record 38 of Set 12 | marfino
# Processing Record 39 of Set 12 | dunedin
# Processing Record 40 of Set 12 | khandbari
# Processing Record 41 of Set 12 | hondo
# Processing Record 42 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 43 of Set 12 | qasigiannguit
# Processing Record 44 of Set 12 | les cayes
# Processing Record 45 of Set 12 | kalaleh
# Processing Record 46 of Set 12 | samana
# Processing Record 47 of Set 12 | zverinogolovskoye
# Processing Record 48 of Set 12 | gboko
# Processing Record 49 of Set 12 | micomeseng
# Processing Record 50 of Set 12 | kashi
# Processing Record 1 of Set 13 | mapili
# Processing Record 2 of Set 13 | matara
# Processing Record 3 of Set 13 | akyab
# Processing Record 4 of Set 13 | santa cruz de la palma
# Processing Record 5 of Set 13 | christchurch
# Processing Record 6 of Set 13 | san cristobal
# Processing Record 7 of Set 13 | carahue
# Processing Record 8 of Set 13 | maniitsoq
# Processing Record 9 of Set 13 | ariano irpino
# Processing Record 10 of Set 13 | campoalegre
# Processing Record 11 of Set 13 | murud
# Processing Record 12 of Set 13 | inhambane
# Processing Record 13 of Set 13 | malakal
# Processing Record 14 of Set 13 | mackay
# Processing Record 15 of Set 13 | oistins
# Processing Record 16 of Set 13 | sydney
# Processing Record 17 of Set 13 | kerema
# Processing Record 18 of Set 13 | port lincoln
# Processing Record 19 of Set 13 | hanting
# Processing Record 20 of Set 13 | cascavel
# Processing Record 21 of Set 13 | nemuro
# Processing Record 22 of Set 13 | karwar
# Processing Record 23 of Set 13 | coracora
# Processing Record 24 of Set 13 | mezen
# Processing Record 25 of Set 13 | kanadukathan
# Processing Record 26 of Set 13 | marzuq
# Processing Record 27 of Set 13 | colimes
# Processing Record 28 of Set 13 | sechura
# Processing Record 29 of Set 13 | asayita
# City not found. Skipping...
# Processing Record 30 of Set 13 | gori
# Processing Record 31 of Set 13 | bilma
# Processing Record 32 of Set 13 | tixtla
# City not found. Skipping...
# Processing Record 33 of Set 13 | nelson bay
# Processing Record 34 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 35 of Set 13 | shelburne
# Processing Record 36 of Set 13 | tiznit
# Processing Record 37 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 38 of Set 13 | thunder bay
# Processing Record 39 of Set 13 | saint-ambroise
# Processing Record 40 of Set 13 | lobito
# Processing Record 41 of Set 13 | nizhneyansk
# City not found. Skipping...
# Processing Record 42 of Set 13 | mahibadhoo
# Processing Record 43 of Set 13 | te anau
# Processing Record 44 of Set 13 | paraiso
# Processing Record 45 of Set 13 | tiverton
# Processing Record 46 of Set 13 | cayce
# Processing Record 47 of Set 13 | buritis
# Processing Record 48 of Set 13 | santa cruz
# Processing Record 49 of Set 13 | tukrah
# Processing Record 50 of Set 13 | rio verde de mato grosso
# Processing Record 1 of Set 14 | beringovskiy
# Processing Record 2 of Set 14 | la ronge
# Processing Record 3 of Set 14 | canico
# Processing Record 4 of Set 14 | whyalla
# Processing Record 5 of Set 14 | ahuimanu
# Processing Record 6 of Set 14 | high level
# Processing Record 7 of Set 14 | dhidhdhoo
# Processing Record 8 of Set 14 | abilene
# Processing Record 9 of Set 14 | catio
# Processing Record 10 of Set 14 | novyy karachay
# Processing Record 11 of Set 14 | aswan
# Processing Record 12 of Set 14 | alekseyevsk
# Processing Record 13 of Set 14 | nhulunbuy
# Processing Record 14 of Set 14 | troitskoye
# Processing Record 15 of Set 14 | falealupo
# City not found. Skipping...
# Processing Record 16 of Set 14 | barcelona
# Processing Record 17 of Set 14 | banmo
# City not found. Skipping...
# Processing Record 18 of Set 14 | vaureal
# Processing Record 19 of Set 14 | najran
# Processing Record 20 of Set 14 | senigallia
# Processing Record 21 of Set 14 | palmer
# Processing Record 22 of Set 14 | puro
# Processing Record 23 of Set 14 | lipay
# Processing Record 24 of Set 14 | dolbeau
# City not found. Skipping...
# Processing Record 25 of Set 14 | chikitigarh
# Processing Record 26 of Set 14 | zacatecoluca
# Processing Record 27 of Set 14 | havre-saint-pierre
# Processing Record 28 of Set 14 | port hardy
# Processing Record 29 of Set 14 | juba
# Processing Record 30 of Set 14 | meridian
# Processing Record 31 of Set 14 | brae
# Processing Record 32 of Set 14 | sabha
# Processing Record 33 of Set 14 | klaksvik
# Processing Record 34 of Set 14 | pionerskiy
# Processing Record 35 of Set 14 | knysna
# Processing Record 36 of Set 14 | salalah
# Processing Record 37 of Set 14 | jasper
# Processing Record 38 of Set 14 | lichuan
# Processing Record 39 of Set 14 | itatskiy
# Processing Record 40 of Set 14 | gimli
# Processing Record 41 of Set 14 | lima
# Processing Record 42 of Set 14 | dongli
# Processing Record 43 of Set 14 | saint anthony
# Processing Record 44 of Set 14 | ijaki
# City not found. Skipping...
# Processing Record 45 of Set 14 | stabat
# Processing Record 46 of Set 14 | san juan
# Processing Record 47 of Set 14 | rabo de peixe
# Processing Record 48 of Set 14 | morehead
# Processing Record 49 of Set 14 | morant bay
# Processing Record 50 of Set 14 | anadyr
# Processing Record 1 of Set 15 | puerto lempira
# Processing Record 2 of Set 15 | ushtobe
# Processing Record 3 of Set 15 | calabasas
# Processing Record 4 of Set 15 | rio gallegos
# Processing Record 5 of Set 15 | estelle
# Processing Record 6 of Set 15 | melbu
# Processing Record 7 of Set 15 | wewak
# Processing Record 8 of Set 15 | kailua
# Processing Record 9 of Set 15 | grand centre
# City not found. Skipping...
# Processing Record 10 of Set 15 | yichang
# Processing Record 11 of Set 15 | san ignacio
# Processing Record 12 of Set 15 | vostok
# Processing Record 13 of Set 15 | triunfo
# Processing Record 14 of Set 15 | namatanai
# Processing Record 15 of Set 15 | kedougou
# Processing Record 16 of Set 15 | dwarka
# Processing Record 17 of Set 15 | tual
# Processing Record 18 of Set 15 | goure
# Processing Record 19 of Set 15 | suruc
# Processing Record 20 of Set 15 | goyty
# Processing Record 21 of Set 15 | darhan
# Processing Record 22 of Set 15 | shibarghan
# City not found. Skipping...
# Processing Record 23 of Set 15 | guasdualito
# Processing Record 24 of Set 15 | quelimane
# Processing Record 25 of Set 15 | jerantut
# Processing Record 26 of Set 15 | lushunkou
# City not found. Skipping...
# Processing Record 27 of Set 15 | kargasok
# Processing Record 28 of Set 15 | nyurba
# Processing Record 29 of Set 15 | mutoko
# Processing Record 30 of Set 15 | petatlan
# Processing Record 31 of Set 15 | bereda
# Processing Record 32 of Set 15 | san pedro
# Processing Record 33 of Set 15 | ouro preto
# Processing Record 34 of Set 15 | kikwit
# Processing Record 35 of Set 15 | ondorhaan
# City not found. Skipping...
# Processing Record 36 of Set 15 | ouesso
# Processing Record 37 of Set 15 | axim
# Processing Record 38 of Set 15 | lebork
# Processing Record 39 of Set 15 | znamenskoye
# Processing Record 40 of Set 15 | havelock
# Processing Record 41 of Set 15 | monte azul
# Processing Record 42 of Set 15 | yamada
# Processing Record 43 of Set 15 | ereymentau
# Processing Record 44 of Set 15 | kanker
# Processing Record 45 of Set 15 | maragogi
# Processing Record 46 of Set 15 | kazanskaya
# Processing Record 47 of Set 15 | mount isa
# Processing Record 48 of Set 15 | sehore
# Processing Record 49 of Set 15 | yantal
# Processing Record 50 of Set 15 | corabia
# Processing Record 1 of Set 16 | kroya
# Processing Record 2 of Set 16 | irbeyskoye
# Processing Record 3 of Set 16 | ornskoldsvik
# Processing Record 4 of Set 16 | komyshnya
# Processing Record 5 of Set 16 | smolenka
# Processing Record 6 of Set 16 | rungata
# City not found. Skipping...
# Processing Record 7 of Set 16 | itaituba
# Processing Record 8 of Set 16 | lask
# Processing Record 9 of Set 16 | ponta delgada
# Processing Record 10 of Set 16 | arshan
# Processing Record 11 of Set 16 | azar shahr
# City not found. Skipping...
# Processing Record 12 of Set 16 | khani
# Processing Record 13 of Set 16 | zonguldak
# Processing Record 14 of Set 16 | okhotsk
# Processing Record 15 of Set 16 | barcelos
# Processing Record 16 of Set 16 | batie
# Processing Record 17 of Set 16 | kupang
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 703

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0    Saint-Philippe      RE -21.36   55.77     73.40        78           0
# 1      Norman Wells      CA  65.28 -126.83     35.60        74          75
# 2          Rosarito      MX  32.33 -117.03     80.60        28          20
# 3             Buala      SB  -8.14  159.59     85.21        67         100
# 4         Cape Town      ZA -33.93   18.42     61.00        59           0
# ..              ...     ...    ...     ...       ...       ...         ...
# 698       Zonguldak      TR  41.25   31.83     39.96        89           8
# 699         Okhotsk      RU  59.38  143.30     -7.31        86          63
# 700        Barcelos      PT  41.54   -8.62     51.01        76           0
# 701           Batie      BF   9.88   -2.92     77.02        21           0
# 702          Kupang      ID -10.17  123.58     77.00       100          40
#
#      Wind Speed Current Description
# 0          6.93           clear sky
# 1          8.05       broken clouds
# 2         10.29          few clouds
# 3          5.99          light rain
# 4         21.92           clear sky
# ..          ...                 ...
# 698        2.35           clear sky
# 699       15.23       broken clouds
# 700        3.36           clear sky
# 701        2.10           clear sky
# 702        3.36          light rain
#
# [703 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# ******** Deliverable 1 - Retrieve Weather Data Complete *****
