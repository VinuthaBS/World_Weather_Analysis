# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities
cities = []
# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bc410ec95229b328ec759306d5e17889

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # read the list to a temp and then read the actual description
        city_weatherdesc = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weatherdesc
                          })

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | lhokseumawe
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | grand gaube
# Processing Record 4 of Set 1 | millerovo
# Processing Record 5 of Set 1 | hofn
# Processing Record 6 of Set 1 | bambous virieux
# Processing Record 7 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 1 | nanortalik
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | hermanus
# Processing Record 11 of Set 1 | esperance
# Processing Record 12 of Set 1 | geraldton
# Processing Record 13 of Set 1 | lebu
# Processing Record 14 of Set 1 | kazalinsk
# City not found. Skipping...
# Processing Record 15 of Set 1 | college
# Processing Record 16 of Set 1 | camapua
# Processing Record 17 of Set 1 | vaini
# Processing Record 18 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 19 of Set 1 | ahuimanu
# Processing Record 20 of Set 1 | rabat
# Processing Record 21 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 22 of Set 1 | sitka
# Processing Record 23 of Set 1 | hualmay
# Processing Record 24 of Set 1 | niigata
# Processing Record 25 of Set 1 | lamu
# Processing Record 26 of Set 1 | champerico
# Processing Record 27 of Set 1 | chokurdakh
# Processing Record 28 of Set 1 | kirakira
# Processing Record 29 of Set 1 | khatanga
# Processing Record 30 of Set 1 | ilebo
# Processing Record 31 of Set 1 | carnarvon
# Processing Record 32 of Set 1 | atuona
# Processing Record 33 of Set 1 | nome
# Processing Record 34 of Set 1 | rawson
# Processing Record 35 of Set 1 | ushuaia
# Processing Record 36 of Set 1 | hobart
# Processing Record 37 of Set 1 | busselton
# Processing Record 38 of Set 1 | san patricio
# Processing Record 39 of Set 1 | doboz
# Processing Record 40 of Set 1 | alofi
# Processing Record 41 of Set 1 | punta alta
# Processing Record 42 of Set 1 | bonfim
# Processing Record 43 of Set 1 | albany
# Processing Record 44 of Set 1 | mataura
# Processing Record 45 of Set 1 | saint-joseph
# Processing Record 46 of Set 1 | bolungarvik
# City not found. Skipping...
# Processing Record 47 of Set 1 | thompson
# Processing Record 48 of Set 1 | kapaa
# Processing Record 49 of Set 1 | dikson
# Processing Record 50 of Set 1 | airai
# Processing Record 1 of Set 2 | cape town
# Processing Record 2 of Set 2 | mangan
# Processing Record 3 of Set 2 | vila velha
# Processing Record 4 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 5 of Set 2 | hirara
# Processing Record 6 of Set 2 | zelenogradsk
# Processing Record 7 of Set 2 | hobyo
# Processing Record 8 of Set 2 | pevek
# Processing Record 9 of Set 2 | narsaq
# Processing Record 10 of Set 2 | plettenberg bay
# Processing Record 11 of Set 2 | novonikolayevskiy
# Processing Record 12 of Set 2 | rio grande
# Processing Record 13 of Set 2 | cervo
# Processing Record 14 of Set 2 | bethel
# Processing Record 15 of Set 2 | pointe michel
# Processing Record 16 of Set 2 | port blair
# Processing Record 17 of Set 2 | butaritari
# Processing Record 18 of Set 2 | victoria
# Processing Record 19 of Set 2 | ribeira grande
# Processing Record 20 of Set 2 | new norfolk
# Processing Record 21 of Set 2 | puerto ayora
# Processing Record 22 of Set 2 | beringovskiy
# Processing Record 23 of Set 2 | kaeo
# Processing Record 24 of Set 2 | brigantine
# Processing Record 25 of Set 2 | necochea
# Processing Record 26 of Set 2 | san quintin
# Processing Record 27 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 2 | hilo
# Processing Record 29 of Set 2 | batagay-alyta
# Processing Record 30 of Set 2 | lugovoy
# Processing Record 31 of Set 2 | neutraubling
# Processing Record 32 of Set 2 | sabang
# Processing Record 33 of Set 2 | port alfred
# Processing Record 34 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 35 of Set 2 | upernavik
# Processing Record 36 of Set 2 | faanui
# Processing Record 37 of Set 2 | sao miguel do araguaia
# Processing Record 38 of Set 2 | vostok
# Processing Record 39 of Set 2 | cherskiy
# Processing Record 40 of Set 2 | bathsheba
# Processing Record 41 of Set 2 | mayumba
# Processing Record 42 of Set 2 | barrow
# Processing Record 43 of Set 2 | ukiah
# Processing Record 44 of Set 2 | san ignacio
# Processing Record 45 of Set 2 | castro
# Processing Record 46 of Set 2 | ponta delgada
# Processing Record 47 of Set 2 | norman wells
# Processing Record 48 of Set 2 | puerto madero
# Processing Record 49 of Set 2 | along
# Processing Record 50 of Set 2 | hithadhoo
# Processing Record 1 of Set 3 | plastun
# Processing Record 2 of Set 3 | cidreira
# Processing Record 3 of Set 3 | high level
# Processing Record 4 of Set 3 | kodiak
# Processing Record 5 of Set 3 | vrangel
# Processing Record 6 of Set 3 | tengushevo
# Processing Record 7 of Set 3 | tura
# Processing Record 8 of Set 3 | vaitape
# Processing Record 9 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 10 of Set 3 | laurel
# Processing Record 11 of Set 3 | bluff
# Processing Record 12 of Set 3 | namtsy
# Processing Record 13 of Set 3 | kavieng
# Processing Record 14 of Set 3 | richards bay
# Processing Record 15 of Set 3 | behat
# Processing Record 16 of Set 3 | nabire
# Processing Record 17 of Set 3 | sembakung
# Processing Record 18 of Set 3 | sierre
# Processing Record 19 of Set 3 | maragogi
# Processing Record 20 of Set 3 | gat
# Processing Record 21 of Set 3 | tubruq
# City not found. Skipping...
# Processing Record 22 of Set 3 | saint-philippe
# Processing Record 23 of Set 3 | fortuna
# Processing Record 24 of Set 3 | rossano
# Processing Record 25 of Set 3 | beidao
# Processing Record 26 of Set 3 | nea vissa
# Processing Record 27 of Set 3 | filadelfia
# Processing Record 28 of Set 3 | guiong
# Processing Record 29 of Set 3 | nantucket
# Processing Record 30 of Set 3 | yumen
# Processing Record 31 of Set 3 | nouadhibou
# Processing Record 32 of Set 3 | ibicarai
# Processing Record 33 of Set 3 | fergus falls
# Processing Record 34 of Set 3 | linhares
# Processing Record 35 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 36 of Set 3 | terra rica
# Processing Record 37 of Set 3 | ust-kut
# Processing Record 38 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 39 of Set 3 | vila franca do campo
# Processing Record 40 of Set 3 | pitimbu
# Processing Record 41 of Set 3 | constitucion
# Processing Record 42 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 43 of Set 3 | cam ranh
# Processing Record 44 of Set 3 | tebingtinggi
# Processing Record 45 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 46 of Set 3 | yellowknife
# Processing Record 47 of Set 3 | cayenne
# Processing Record 48 of Set 3 | andrelandia
# Processing Record 49 of Set 3 | belaya gora
# Processing Record 50 of Set 3 | luderitz
# Processing Record 1 of Set 4 | tuktoyaktuk
# Processing Record 2 of Set 4 | jalu
# Processing Record 3 of Set 4 | mar del plata
# Processing Record 4 of Set 4 | provideniya
# Processing Record 5 of Set 4 | namatanai
# Processing Record 6 of Set 4 | ancud
# Processing Record 7 of Set 4 | bundaberg
# Processing Record 8 of Set 4 | trenton
# Processing Record 9 of Set 4 | burgos
# Processing Record 10 of Set 4 | saldanha
# Processing Record 11 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 12 of Set 4 | jamestown
# Processing Record 13 of Set 4 | asau
# Processing Record 14 of Set 4 | mergui
# City not found. Skipping...
# Processing Record 15 of Set 4 | bredasdorp
# Processing Record 16 of Set 4 | sobolevo
# Processing Record 17 of Set 4 | andenes
# Processing Record 18 of Set 4 | mehamn
# Processing Record 19 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 20 of Set 4 | suntar
# Processing Record 21 of Set 4 | alice springs
# Processing Record 22 of Set 4 | longyearbyen
# Processing Record 23 of Set 4 | broken hill
# Processing Record 24 of Set 4 | rio gallegos
# Processing Record 25 of Set 4 | huarmey
# Processing Record 26 of Set 4 | korla
# Processing Record 27 of Set 4 | sao filipe
# Processing Record 28 of Set 4 | darhan
# Processing Record 29 of Set 4 | pedernales
# Processing Record 30 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 31 of Set 4 | baft
# Processing Record 32 of Set 4 | mahibadhoo
# Processing Record 33 of Set 4 | bubaque
# Processing Record 34 of Set 4 | inirida
# Processing Record 35 of Set 4 | kavaratti
# Processing Record 36 of Set 4 | tullamore
# Processing Record 37 of Set 4 | kangaatsiaq
# Processing Record 38 of Set 4 | ilulissat
# Processing Record 39 of Set 4 | coquimbo
# Processing Record 40 of Set 4 | elk
# Processing Record 41 of Set 4 | zelenoborsk
# Processing Record 42 of Set 4 | mahebourg
# Processing Record 43 of Set 4 | khani
# Processing Record 44 of Set 4 | trairi
# Processing Record 45 of Set 4 | neiafu
# Processing Record 46 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 47 of Set 4 | ketchikan
# Processing Record 48 of Set 4 | ha giang
# Processing Record 49 of Set 4 | kahului
# Processing Record 50 of Set 4 | male
# Processing Record 1 of Set 5 | klaksvik
# Processing Record 2 of Set 5 | batagay
# Processing Record 3 of Set 5 | broome
# Processing Record 4 of Set 5 | robertsport
# Processing Record 5 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 6 of Set 5 | svetlaya
# Processing Record 7 of Set 5 | iqaluit
# Processing Record 8 of Set 5 | nenjiang
# Processing Record 9 of Set 5 | ulladulla
# Processing Record 10 of Set 5 | arsikere
# Processing Record 11 of Set 5 | cabo san lucas
# Processing Record 12 of Set 5 | avarua
# Processing Record 13 of Set 5 | pital
# Processing Record 14 of Set 5 | nikolskoye
# Processing Record 15 of Set 5 | karakol
# Processing Record 16 of Set 5 | viransehir
# Processing Record 17 of Set 5 | polis
# Processing Record 18 of Set 5 | asfi
# Processing Record 19 of Set 5 | flic en flac
# Processing Record 20 of Set 5 | soto la marina
# Processing Record 21 of Set 5 | gamba
# Processing Record 22 of Set 5 | la peca
# Processing Record 23 of Set 5 | dalton
# Processing Record 24 of Set 5 | kupang
# Processing Record 25 of Set 5 | aklavik
# Processing Record 26 of Set 5 | mount gambier
# Processing Record 27 of Set 5 | ponta do sol
# Processing Record 28 of Set 5 | xai-xai
# Processing Record 29 of Set 5 | paranaiba
# Processing Record 30 of Set 5 | opuwo
# Processing Record 31 of Set 5 | half moon bay
# Processing Record 32 of Set 5 | lavrentiya
# Processing Record 33 of Set 5 | vardo
# Processing Record 34 of Set 5 | kindu
# Processing Record 35 of Set 5 | watsa
# Processing Record 36 of Set 5 | anchorage
# Processing Record 37 of Set 5 | suluq
# Processing Record 38 of Set 5 | hasaki
# Processing Record 39 of Set 5 | salalah
# Processing Record 40 of Set 5 | lompoc
# Processing Record 41 of Set 5 | bandarbeyla
# Processing Record 42 of Set 5 | olafsvik
# Processing Record 43 of Set 5 | emerald
# Processing Record 44 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 45 of Set 5 | worthington
# Processing Record 46 of Set 5 | araouane
# Processing Record 47 of Set 5 | gisborne
# Processing Record 48 of Set 5 | east london
# Processing Record 49 of Set 5 | ibra
# Processing Record 50 of Set 5 | taree
# Processing Record 1 of Set 6 | rafraf
# Processing Record 2 of Set 6 | gushikawa
# Processing Record 3 of Set 6 | najran
# Processing Record 4 of Set 6 | umm lajj
# Processing Record 5 of Set 6 | kaitangata
# Processing Record 6 of Set 6 | dawlatabad
# Processing Record 7 of Set 6 | oussouye
# Processing Record 8 of Set 6 | georgetown
# Processing Record 9 of Set 6 | valentin gomez farias
# Processing Record 10 of Set 6 | beloha
# Processing Record 11 of Set 6 | cheuskiny
# City not found. Skipping...
# Processing Record 12 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 13 of Set 6 | aloleng
# Processing Record 14 of Set 6 | pandamatenga
# Processing Record 15 of Set 6 | jishou
# Processing Record 16 of Set 6 | mutsu
# Processing Record 17 of Set 6 | doliana
# Processing Record 18 of Set 6 | saskylakh
# Processing Record 19 of Set 6 | kenai
# Processing Record 20 of Set 6 | santa cruz de la palma
# Processing Record 21 of Set 6 | brae
# Processing Record 22 of Set 6 | marsabit
# Processing Record 23 of Set 6 | kendari
# Processing Record 24 of Set 6 | itarema
# Processing Record 25 of Set 6 | la gaulette
# City not found. Skipping...
# Processing Record 26 of Set 6 | port elizabeth
# Processing Record 27 of Set 6 | beliu
# Processing Record 28 of Set 6 | swellendam
# Processing Record 29 of Set 6 | yanliang
# Processing Record 30 of Set 6 | sao joaquim
# Processing Record 31 of Set 6 | aflu
# City not found. Skipping...
# Processing Record 32 of Set 6 | burgersdorp
# Processing Record 33 of Set 6 | mut
# Processing Record 34 of Set 6 | hyeres
# Processing Record 35 of Set 6 | fairbanks
# Processing Record 36 of Set 6 | flinders
# Processing Record 37 of Set 6 | masallatah
# Processing Record 38 of Set 6 | san policarpo
# Processing Record 39 of Set 6 | lagoa
# Processing Record 40 of Set 6 | arraial do cabo
# Processing Record 41 of Set 6 | pontypridd
# Processing Record 42 of Set 6 | qaanaaq
# Processing Record 43 of Set 6 | severo-kurilsk
# Processing Record 44 of Set 6 | tiksi
# Processing Record 45 of Set 6 | tuatapere
# Processing Record 46 of Set 6 | bengkulu
# Processing Record 47 of Set 6 | kaseda
# Processing Record 48 of Set 6 | arman
# Processing Record 49 of Set 6 | portland
# Processing Record 50 of Set 6 | la ronge
# Processing Record 1 of Set 7 | north bend
# Processing Record 2 of Set 7 | fayaoue
# Processing Record 3 of Set 7 | torbay
# Processing Record 4 of Set 7 | pangnirtung
# Processing Record 5 of Set 7 | elizabeth city
# Processing Record 6 of Set 7 | kazuno
# Processing Record 7 of Set 7 | ust-kulom
# Processing Record 8 of Set 7 | faya
# Processing Record 9 of Set 7 | maracas
# Processing Record 10 of Set 7 | stornoway
# Processing Record 11 of Set 7 | lake havasu city
# Processing Record 12 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 13 of Set 7 | les cayes
# Processing Record 14 of Set 7 | clyde river
# Processing Record 15 of Set 7 | kstovo
# Processing Record 16 of Set 7 | buraydah
# Processing Record 17 of Set 7 | dingle
# Processing Record 18 of Set 7 | sorong
# Processing Record 19 of Set 7 | baculin
# Processing Record 20 of Set 7 | rosemount
# Processing Record 21 of Set 7 | yenagoa
# Processing Record 22 of Set 7 | meulaboh
# Processing Record 23 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 24 of Set 7 | komsomolskiy
# Processing Record 25 of Set 7 | paveh
# Processing Record 26 of Set 7 | bud
# Processing Record 27 of Set 7 | nyurba
# Processing Record 28 of Set 7 | avera
# Processing Record 29 of Set 7 | bereda
# Processing Record 30 of Set 7 | namibe
# Processing Record 31 of Set 7 | cordoba
# Processing Record 32 of Set 7 | lazaro cardenas
# Processing Record 33 of Set 7 | hambantota
# Processing Record 34 of Set 7 | kyren
# Processing Record 35 of Set 7 | safwah
# City not found. Skipping...
# Processing Record 36 of Set 7 | pisco
# Processing Record 37 of Set 7 | beyneu
# Processing Record 38 of Set 7 | marrakesh
# Processing Record 39 of Set 7 | weihe
# Processing Record 40 of Set 7 | port antonio
# Processing Record 41 of Set 7 | nokia
# Processing Record 42 of Set 7 | oktyabrskiy
# Processing Record 43 of Set 7 | saint george
# Processing Record 44 of Set 7 | novo aripuana
# Processing Record 45 of Set 7 | praya
# Processing Record 46 of Set 7 | maniitsoq
# Processing Record 47 of Set 7 | korem
# Processing Record 48 of Set 7 | naze
# Processing Record 49 of Set 7 | gunjur
# Processing Record 50 of Set 7 | tanuku
# Processing Record 1 of Set 8 | jinchang
# Processing Record 2 of Set 8 | la orilla
# Processing Record 3 of Set 8 | mandurah
# Processing Record 4 of Set 8 | tabou
# Processing Record 5 of Set 8 | znamenskoye
# Processing Record 6 of Set 8 | souillac
# Processing Record 7 of Set 8 | fort nelson
# Processing Record 8 of Set 8 | ashqelon
# Processing Record 9 of Set 8 | muros
# Processing Record 10 of Set 8 | verkhnyachka
# Processing Record 11 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 12 of Set 8 | nhulunbuy
# Processing Record 13 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 14 of Set 8 | caucaia
# Processing Record 15 of Set 8 | ngunguru
# Processing Record 16 of Set 8 | nelson
# Processing Record 17 of Set 8 | neuquen
# Processing Record 18 of Set 8 | ponnani
# Processing Record 19 of Set 8 | lorengau
# Processing Record 20 of Set 8 | thunder bay
# Processing Record 21 of Set 8 | smithers
# Processing Record 22 of Set 8 | morros
# Processing Record 23 of Set 8 | haines junction
# Processing Record 24 of Set 8 | mazamari
# Processing Record 25 of Set 8 | saint-leu
# Processing Record 26 of Set 8 | antiguo morelos
# Processing Record 27 of Set 8 | suihua
# Processing Record 28 of Set 8 | matay
# Processing Record 29 of Set 8 | stege
# Processing Record 30 of Set 8 | sorland
# Processing Record 31 of Set 8 | vanimo
# Processing Record 32 of Set 8 | noumea
# Processing Record 33 of Set 8 | biloela
# Processing Record 34 of Set 8 | yabrud
# Processing Record 35 of Set 8 | uglegorsk
# Processing Record 36 of Set 8 | vryburg
# Processing Record 37 of Set 8 | svetlogorsk
# Processing Record 38 of Set 8 | balikpapan
# Processing Record 39 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 40 of Set 8 | san luis de palenque
# Processing Record 41 of Set 8 | grindavik
# Processing Record 42 of Set 8 | sao joao da barra
# Processing Record 43 of Set 8 | lakatoro
# Processing Record 44 of Set 8 | somerset east
# Processing Record 45 of Set 8 | antofagasta
# Processing Record 46 of Set 8 | mana
# Processing Record 47 of Set 8 | mangrol
# Processing Record 48 of Set 8 | mbanza-ngungu
# Processing Record 49 of Set 8 | skjervoy
# Processing Record 50 of Set 8 | sladkovo
# Processing Record 1 of Set 9 | abakaliki
# Processing Record 2 of Set 9 | denau
# City not found. Skipping...
# Processing Record 3 of Set 9 | berlevag
# Processing Record 4 of Set 9 | itaguai
# Processing Record 5 of Set 9 | gillette
# Processing Record 6 of Set 9 | ostrovnoy
# Processing Record 7 of Set 9 | walvis bay
# Processing Record 8 of Set 9 | evensk
# Processing Record 9 of Set 9 | matara
# Processing Record 10 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 11 of Set 9 | sulangan
# Processing Record 12 of Set 9 | aitape
# Processing Record 13 of Set 9 | amasya
# Processing Record 14 of Set 9 | yar-sale
# Processing Record 15 of Set 9 | kondagaon
# Processing Record 16 of Set 9 | roma
# Processing Record 17 of Set 9 | gorontalo
# Processing Record 18 of Set 9 | kamiiso
# Processing Record 19 of Set 9 | mugur-aksy
# Processing Record 20 of Set 9 | lakes entrance
# Processing Record 21 of Set 9 | mawlaik
# Processing Record 22 of Set 9 | byron bay
# Processing Record 23 of Set 9 | belmonte
# Processing Record 24 of Set 9 | kalabo
# Processing Record 25 of Set 9 | aguimes
# Processing Record 26 of Set 9 | abalak
# Processing Record 27 of Set 9 | xuddur
# Processing Record 28 of Set 9 | shitkino
# Processing Record 29 of Set 9 | shimoda
# Processing Record 30 of Set 9 | pandrup
# Processing Record 31 of Set 9 | tongling
# Processing Record 32 of Set 9 | chipinge
# Processing Record 33 of Set 9 | eureka
# Processing Record 34 of Set 9 | linxia
# Processing Record 35 of Set 9 | tasiilaq
# Processing Record 36 of Set 9 | liyang
# Processing Record 37 of Set 9 | sainte-maxime
# Processing Record 38 of Set 9 | kazachinskoye
# Processing Record 39 of Set 9 | chengmai
# City not found. Skipping...
# Processing Record 40 of Set 9 | codrington
# Processing Record 41 of Set 9 | aguilas
# Processing Record 42 of Set 9 | bac lieu
# Processing Record 43 of Set 9 | awjilah
# Processing Record 44 of Set 9 | moron
# Processing Record 45 of Set 9 | qingquan
# Processing Record 46 of Set 9 | charagua
# Processing Record 47 of Set 9 | katsuura
# Processing Record 48 of Set 9 | nadym
# Processing Record 49 of Set 9 | koslan
# Processing Record 50 of Set 9 | peniche
# Processing Record 1 of Set 10 | trincomalee
# Processing Record 2 of Set 10 | baza
# Processing Record 3 of Set 10 | boksitogorsk
# Processing Record 4 of Set 10 | tayoltita
# Processing Record 5 of Set 10 | kropotkin
# Processing Record 6 of Set 10 | kermanshah
# Processing Record 7 of Set 10 | lavumisa
# Processing Record 8 of Set 10 | xining
# Processing Record 9 of Set 10 | touros
# Processing Record 10 of Set 10 | parainen
# Processing Record 11 of Set 10 | chibuto
# Processing Record 12 of Set 10 | boshnyakovo
# Processing Record 13 of Set 10 | pacific grove
# Processing Record 14 of Set 10 | saint anthony
# Processing Record 15 of Set 10 | chuy
# Processing Record 16 of Set 10 | saint-ambroise
# Processing Record 17 of Set 10 | rudnichnyy
# Processing Record 18 of Set 10 | port-gentil
# Processing Record 19 of Set 10 | buckeye
# Processing Record 20 of Set 10 | makat
# Processing Record 21 of Set 10 | vao
# Processing Record 22 of Set 10 | yerbogachen
# Processing Record 23 of Set 10 | kyritz
# Processing Record 24 of Set 10 | berea
# Processing Record 25 of Set 10 | san cristobal
# Processing Record 26 of Set 10 | le port
# Processing Record 27 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 28 of Set 10 | lodja
# Processing Record 29 of Set 10 | banjar
# Processing Record 30 of Set 10 | lashio
# Processing Record 31 of Set 10 | barmer
# Processing Record 32 of Set 10 | udachnyy
# Processing Record 33 of Set 10 | tevriz
# Processing Record 34 of Set 10 | miracema do tocantins
# Processing Record 35 of Set 10 | thinadhoo
# Processing Record 36 of Set 10 | berdigestyakh
# Processing Record 37 of Set 10 | vanavara
# Processing Record 38 of Set 10 | esso
# Processing Record 39 of Set 10 | saint-pierre
# Processing Record 40 of Set 10 | bridgetown
# Processing Record 41 of Set 10 | bucerias
# Processing Record 42 of Set 10 | zhezkazgan
# Processing Record 43 of Set 10 | sakaiminato
# Processing Record 44 of Set 10 | mozarlandia
# Processing Record 45 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 46 of Set 10 | grand-santi
# Processing Record 47 of Set 10 | victor harbor
# Processing Record 48 of Set 10 | henties bay
# Processing Record 49 of Set 10 | ayan
# Processing Record 50 of Set 10 | davidson
# Processing Record 1 of Set 11 | tasbuget
# City not found. Skipping...
# Processing Record 2 of Set 11 | onguday
# Processing Record 3 of Set 11 | lodeynoye pole
# Processing Record 4 of Set 11 | derzhavinsk
# Processing Record 5 of Set 11 | murmashi
# Processing Record 6 of Set 11 | hovd
# Processing Record 7 of Set 11 | santa isabel do rio negro
# Processing Record 8 of Set 11 | butembo
# Processing Record 9 of Set 11 | port hedland
# Processing Record 10 of Set 11 | verkhnevilyuysk
# Processing Record 11 of Set 11 | yarensk
# Processing Record 12 of Set 11 | havoysund
# Processing Record 13 of Set 11 | adrar
# Processing Record 14 of Set 11 | sao lourenco do sul
# Processing Record 15 of Set 11 | ixtapa
# Processing Record 16 of Set 11 | san rafael
# Processing Record 17 of Set 11 | kruisfontein
# Processing Record 18 of Set 11 | melilla
# Processing Record 19 of Set 11 | presidencia roque saenz pena
# Processing Record 20 of Set 11 | redcliffe
# Processing Record 21 of Set 11 | lagos de moreno
# Processing Record 22 of Set 11 | bahir dar
# Processing Record 23 of Set 11 | jaciara
# Processing Record 24 of Set 11 | iwanai
# Processing Record 25 of Set 11 | tahe
# Processing Record 26 of Set 11 | verkhnyaya toyma
# Processing Record 27 of Set 11 | sumbawa
# City not found. Skipping...
# Processing Record 28 of Set 11 | kamaishi
# Processing Record 29 of Set 11 | ingham
# Processing Record 30 of Set 11 | cap-chat
# Processing Record 31 of Set 11 | plainview
# Processing Record 32 of Set 11 | am timan
# Processing Record 33 of Set 11 | acarau
# Processing Record 34 of Set 11 | eydhafushi
# Processing Record 35 of Set 11 | hay river
# Processing Record 36 of Set 11 | laguna
# Processing Record 37 of Set 11 | sedelnikovo
# City not found. Skipping...
# Processing Record 38 of Set 11 | sechura
# Processing Record 39 of Set 11 | chapais
# Processing Record 40 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 41 of Set 11 | sinjai
# Processing Record 42 of Set 11 | morondava
# Processing Record 43 of Set 11 | save
# Processing Record 44 of Set 11 | manturovo
# Processing Record 45 of Set 11 | bad munstereifel
# Processing Record 46 of Set 11 | coihaique
# Processing Record 47 of Set 11 | kuryk
# Processing Record 48 of Set 11 | olinda
# Processing Record 49 of Set 11 | boende
# Processing Record 50 of Set 11 | clarksburg
# Processing Record 1 of Set 12 | tuggurt
# City not found. Skipping...
# Processing Record 2 of Set 12 | tsiroanomandidy
# Processing Record 3 of Set 12 | te anau
# Processing Record 4 of Set 12 | uvalde
# Processing Record 5 of Set 12 | simpang
# Processing Record 6 of Set 12 | astana
# Processing Record 7 of Set 12 | santa isabel
# Processing Record 8 of Set 12 | yaan
# Processing Record 9 of Set 12 | sakakah
# Processing Record 10 of Set 12 | seinajoki
# Processing Record 11 of Set 12 | waipawa
# Processing Record 12 of Set 12 | yatou
# Processing Record 13 of Set 12 | zhigansk
# Processing Record 14 of Set 12 | mbandaka
# Processing Record 15 of Set 12 | sinnai
# Processing Record 16 of Set 12 | san ramon
# Processing Record 17 of Set 12 | bogorodskoye
# Processing Record 18 of Set 12 | mitsamiouli
# Processing Record 19 of Set 12 | hailey
# Processing Record 20 of Set 12 | honningsvag
# Processing Record 21 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 22 of Set 12 | shingu
# Processing Record 23 of Set 12 | vilshofen
# Processing Record 24 of Set 12 | pachino
# Processing Record 25 of Set 12 | samarai
# Processing Record 26 of Set 12 | isangel
# Processing Record 27 of Set 12 | bronnoysund
# Processing Record 28 of Set 12 | nuevo progreso
# Processing Record 29 of Set 12 | buluang
# Processing Record 30 of Set 12 | semnan
# Processing Record 31 of Set 12 | ercis
# Processing Record 32 of Set 12 | san juan de arama
# Processing Record 33 of Set 12 | cockburn town
# Processing Record 34 of Set 12 | chicama
# Processing Record 35 of Set 12 | manaure
# Processing Record 36 of Set 12 | churapcha
# Processing Record 37 of Set 12 | bousso
# Processing Record 38 of Set 12 | krasnoselkup
# Processing Record 39 of Set 12 | atar
# Processing Record 40 of Set 12 | cururupu
# Processing Record 41 of Set 12 | dicabisagan
# Processing Record 42 of Set 12 | kualakapuas
# Processing Record 43 of Set 12 | varhaug
# Processing Record 44 of Set 12 | farim
# Processing Record 45 of Set 12 | oranjemund
# Processing Record 46 of Set 12 | dunmore east
# Processing Record 47 of Set 12 | westport
# Processing Record 48 of Set 12 | sangar
# Processing Record 49 of Set 12 | gladstone
# Processing Record 50 of Set 12 | dharur
# Processing Record 1 of Set 13 | sovetskaya gavan
# Processing Record 2 of Set 13 | sibolga
# Processing Record 3 of Set 13 | barra
# Processing Record 4 of Set 13 | bidor
# Processing Record 5 of Set 13 | ossora
# Processing Record 6 of Set 13 | port macquarie
# Processing Record 7 of Set 13 | basco
# Processing Record 8 of Set 13 | ozgon
# City not found. Skipping...
# Processing Record 9 of Set 13 | boddam
# Processing Record 10 of Set 13 | morristown
# Processing Record 11 of Set 13 | uvarovka
# Processing Record 12 of Set 13 | lokosovo
# Processing Record 13 of Set 13 | mumford
# Processing Record 14 of Set 13 | shyroke
# Processing Record 15 of Set 13 | linares
# Processing Record 16 of Set 13 | zalantun
# Processing Record 17 of Set 13 | khanpur
# Processing Record 18 of Set 13 | caravelas
# Processing Record 19 of Set 13 | fevralsk
# City not found. Skipping...
# Processing Record 20 of Set 13 | kilindoni
# Processing Record 21 of Set 13 | port shepstone
# Processing Record 22 of Set 13 | kovin
# Processing Record 23 of Set 13 | yulara
# Processing Record 24 of Set 13 | mildura
# Processing Record 25 of Set 13 | tubuala
# Processing Record 26 of Set 13 | tres arroyos
# Processing Record 27 of Set 13 | bodden town
# Processing Record 28 of Set 13 | coralville
# Processing Record 29 of Set 13 | sheregesh
# Processing Record 30 of Set 13 | huilong
# Processing Record 31 of Set 13 | tateyama
# Processing Record 32 of Set 13 | iznoski
# Processing Record 33 of Set 13 | kudahuvadhoo
# Processing Record 34 of Set 13 | sistranda
# Processing Record 35 of Set 13 | iroquois falls
# Processing Record 36 of Set 13 | ulaanbaatar
# Processing Record 37 of Set 13 | palmer
# Processing Record 38 of Set 13 | namanga
# Processing Record 39 of Set 13 | santa fe
# Processing Record 40 of Set 13 | puerto carreno
# Processing Record 41 of Set 13 | kununurra
# Processing Record 42 of Set 13 | arlit
# Processing Record 43 of Set 13 | tungkang
# City not found. Skipping...
# Processing Record 44 of Set 13 | wells
# Processing Record 45 of Set 13 | monopoli
# Processing Record 46 of Set 13 | disraeli
# Processing Record 47 of Set 13 | cumaribo
# City not found. Skipping...
# Processing Record 48 of Set 13 | kurilsk
# Processing Record 49 of Set 13 | cumpas
# Processing Record 50 of Set 13 | angra
# City not found. Skipping...
# Processing Record 1 of Set 14 | gizo
# Processing Record 2 of Set 14 | sterling
# Processing Record 3 of Set 14 | nouakchott
# Processing Record 4 of Set 14 | kasane
# Processing Record 5 of Set 14 | bone
# Processing Record 6 of Set 14 | betare oya
# Processing Record 7 of Set 14 | beira
# Processing Record 8 of Set 14 | nayagarh
# Processing Record 9 of Set 14 | parrita
# Processing Record 10 of Set 14 | la solana
# Processing Record 11 of Set 14 | jiddah
# City not found. Skipping...
# Processing Record 12 of Set 14 | karpogory
# Processing Record 13 of Set 14 | kombai
# Processing Record 14 of Set 14 | demba
# Processing Record 15 of Set 14 | zeya
# Processing Record 16 of Set 14 | dunedin
# Processing Record 17 of Set 14 | sinnamary
# Processing Record 18 of Set 14 | cap-aux-meules
# Processing Record 19 of Set 14 | ust-charyshskaya pristan
# Processing Record 20 of Set 14 | akcakoca
# Processing Record 21 of Set 14 | guerrero negro
# Processing Record 22 of Set 14 | nioro
# Processing Record 23 of Set 14 | saint-cyr-sur-loire
# Processing Record 24 of Set 14 | dubovyy umet
# Processing Record 25 of Set 14 | menongue
# Processing Record 26 of Set 14 | daru
# Processing Record 27 of Set 14 | barreiras
# Processing Record 28 of Set 14 | shieli
# Processing Record 29 of Set 14 | varnamo
# Processing Record 30 of Set 14 | lengshuijiang
# Processing Record 31 of Set 14 | omagh
# Processing Record 32 of Set 14 | cap malheureux
# Processing Record 33 of Set 14 | morinville
# Processing Record 34 of Set 14 | gazojak
# Processing Record 35 of Set 14 | wamba
# Processing Record 36 of Set 14 | vitim
# Processing Record 37 of Set 14 | anajatuba
# Processing Record 38 of Set 14 | mackay
# Processing Record 39 of Set 14 | matagami
# Processing Record 40 of Set 14 | axim
# Processing Record 41 of Set 14 | makakilo city
# Processing Record 42 of Set 14 | george
# Processing Record 43 of Set 14 | kungurtug
# Processing Record 44 of Set 14 | bowen
# Processing Record 45 of Set 14 | saint-augustin
# Processing Record 46 of Set 14 | beni mazar
# Processing Record 47 of Set 14 | odweyne
# Processing Record 48 of Set 14 | anar darreh
# City not found. Skipping...
# Processing Record 49 of Set 14 | rodrigues alves
# Processing Record 50 of Set 14 | mananjary
# Processing Record 1 of Set 15 | kearney
# Processing Record 2 of Set 15 | dongzhen
# Processing Record 3 of Set 15 | zhangye
# Processing Record 4 of Set 15 | uige
# Processing Record 5 of Set 15 | anadyr
# Processing Record 6 of Set 15 | gullhaug
# Processing Record 7 of Set 15 | warangal
# Processing Record 8 of Set 15 | badhni kalan
# Processing Record 9 of Set 15 | lagos
# Processing Record 10 of Set 15 | mareeba
# Processing Record 11 of Set 15 | camacha
# Processing Record 12 of Set 15 | tommot
# Processing Record 13 of Set 15 | hamilton
# Processing Record 14 of Set 15 | suamico
# Processing Record 15 of Set 15 | porlamar
# Processing Record 16 of Set 15 | alekseyevskoye
# Processing Record 17 of Set 15 | yunjinghong
# City not found. Skipping...
# Processing Record 18 of Set 15 | pergamino
# Processing Record 19 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 20 of Set 15 | luanda
# Processing Record 21 of Set 15 | bramming
# Processing Record 22 of Set 15 | sozimskiy
# Processing Record 23 of Set 15 | talcahuano
# Processing Record 24 of Set 15 | marawi
# Processing Record 25 of Set 15 | kemijarvi
# Processing Record 26 of Set 15 | nejapa
# Processing Record 27 of Set 15 | shelburne
# Processing Record 28 of Set 15 | cabedelo
# Processing Record 29 of Set 15 | bay city
# Processing Record 30 of Set 15 | sambava
# Processing Record 31 of Set 15 | karratha
# Processing Record 32 of Set 15 | pangoa
# Processing Record 33 of Set 15 | bardiyah
# Processing Record 34 of Set 15 | carupano
# Processing Record 35 of Set 15 | maceio
# Processing Record 36 of Set 15 | roches noires
# City not found. Skipping...
# Processing Record 37 of Set 15 | kitui
# Processing Record 38 of Set 15 | tual
# Processing Record 39 of Set 15 | nagato
# Processing Record 40 of Set 15 | changtu
# Processing Record 41 of Set 15 | cartagena del chaira
# Processing Record 42 of Set 15 | atoyatempan
# Processing Record 43 of Set 15 | ugoofaaru
# Processing Record 44 of Set 15 | sioux lookout
# Processing Record 45 of Set 15 | alta floresta
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 694

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                      City Country    Lat     Lng  Max Temp  Humidity  \
# 0             Lhokseumawe      ID   5.18   97.15     77.02        85
# 1                 Rikitea      PF -23.12 -134.97     76.15        70
# 2             Grand Gaube      MU -20.01   57.66     77.00        78
# 3               Millerovo      RU  48.92   40.40     25.25        84
# 4                    Hofn      IS  64.25  -15.21     28.44        88
# ..                    ...     ...    ...     ...       ...       ...
# 689  Cartagena Del Chaira      CO   1.33  -74.84     91.33        45
# 690           Atoyatempan      MX  18.82  -97.92     73.99        44
# 691             Ugoofaaru      MV   5.67   73.00     82.11        72
# 692         Sioux Lookout      CA  50.10  -91.92     28.40        68
# 693         Alta Floresta      BR  -9.88  -56.09     80.60        69
#
#      Cloudiness  Wind Speed Current Description
# 0           100        2.15          light rain
# 1             0        4.79           clear sky
# 2            99        4.00     overcast clouds
# 3           100       15.88     overcast clouds
# 4           100       36.53     overcast clouds
# ..          ...         ...                 ...
# 689          11        7.43          few clouds
# 690          74        5.01       broken clouds
# 691         100       11.99     overcast clouds
# 692          20        5.82          few clouds
# 693          75       12.75        thunderstorm
#
# [694 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# ******** Deliverable 1 - Retrieve Weather Data Complete *****
